# %%
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

from nltk.tokenize import word_tokenize
from nltk import pos_tag
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jessicahong/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/jessicahong/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
from IPython.display import display, HTML
POS_COLORS = {
    'NN': 'blue',     # nouns
    'VB': 'red',      # verbs
    'JJ': 'green',    # adjectives
    'RB': 'purple',   # adverbs
}


def color_pos(tagged_sentence):
    html_parts = []
    for token, tag in tagged_sentence:
        prefix = tag[:2]   # NN, VB, JJ, RB
        color = POS_COLORS.get(prefix, 'black')
        html_parts.append(f"<span style='color:{color}'>{token}({tag})</span>")
    display(HTML(" ".join(html_parts)))

# %%
def pos_tag_sentence(sentence):
    tokens = word_tokenize(sentence)
    return pos_tag(tokens)


def run_pos_experiment(sentences):
    results = {}
    for sent in sentences:
        results[sent] = pos_tag_sentence(sent)
    return results


def inspect(results):
    for sent, tagged in results.items():
        print(f"\nSentence: {sent}")
        color_pos(tagged) 


sentences = [
    "I am happy",
    "Apple is looking at buying U.K. startup for $1 billion",
    "나는 오늘 숙제를 했다",
    "춥네요",
    "ㅊㅋㅊㅋ",
    "그건 좀 어려울 것 같아요"
]

results = run_pos_experiment(sentences)
inspect(results)
# Out:
# Sentence: I am happy
# <span style='color:black'>I(PRP)</span> <span style='color:red'>am(VBP)</span> <span style='color:green'>happy(JJ)</span>
# Sentence: Apple is looking at buying U.K. startup for $1 billion
# <span style='color:blue'>Apple(NNP)</span> <span style='color:red'>is(VBZ)</span> <span style='color:red'>looking(VBG)</span> <span style='color:black'>at(IN)</span> <span style='color:red'>buying(VBG)</span> <span style='color:blue'>U.K.(NNP)</span> <span style='color:blue'>startup(NN)</span> <span style='color:black'>for(IN)</span> <span style='color:black'>$($)</span> <span style='color:black'>1(CD)</span> <span style='color:black'>billion(CD)</span>
# Sentence: 나는 오늘 숙제를 했다
# <span style='color:green'>나는(JJ)</span> <span style='color:blue'>오늘(NNP)</span> <span style='color:blue'>숙제를(NNP)</span> <span style='color:blue'>했다(NN)</span>
# Sentence: 춥네요
# <span style='color:blue'>춥네요(NN)</span>
# Sentence: ㅊㅋㅊㅋ
# <span style='color:blue'>ㅊㅋㅊㅋ(NN)</span>
# ...

# %%
from IPython.display import display, HTML

def test_color():
    display(HTML("<span style='color:red'>RED TEST</span> <span style='color:blue'>BLUE TEST</span>"))

test_color()
# Out:
# <span style='color:red'>RED TEST</span> <span style='color:blue'>BLUE TEST</span>

# %%
tagged = pos_tag_sentence("I am happy")

# %%
color_pos(tagged)
# Out:
# <span style='color:black'>I(PRP)</span> <span style='color:red'>am(VBP)</span> <span style='color:green'>happy(JJ)</span>
